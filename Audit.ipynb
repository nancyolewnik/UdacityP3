# %% [markdown]
# # 1. Data Audit

# %%
# %%writefile mapparser.py
#!/usr/bin/env python

import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
import collections

# %%
import os
datadir = "."
datafile = "DenverCO.osm"
denver_data = os.path.join(datadir, datafile)

OSM_FILE = "./DenverCO.osm"
SAMPLE_FILE = "DenverCO_sample.osm"

# %%
#Parse through the file with ElementTree and count the number of unique element types to understand overall structure.
def count_tags(filename):
        tags = {}
        print filename
        
        for event, elem in ET.iterparse(filename):
            
            if elem.tag in tags:
                tags[elem.tag] += 1
            else:
                tags[elem.tag] = 1
        return tags
    
tags = count_tags(SAMPLE_FILE)
pprint.pprint(tags)
# Out:
# DenverCO_sample.osm
# {'member': 2117,
#  'nd': 240131,
#  'node': 200867,
#  'osm': 1,
#  'relation': 119,
#  'tag': 132958,
#  'way': 26565}

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def get_element(osm_file, tags=('node','way')):
     context = ET.iterparse(osm_file, events=('start','end'))
     _, root = next(context) 
     for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

def key_type(element, keys):
    if element.tag == "node" or element.tag == "way":
        for tag in element.iter('tag'):
            k = tag.get('k')
            if lower.search(k):
                keys['lower'] += 1
            elif lower_colon.search(k):
                keys['lower_colon'] += 1
            elif problemchars.search(k):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in enumerate(get_element(filename)):
        keys = key_type(element, keys)

    return keys

denver_keys = process_map(SAMPLE_FILE)
pprint.pprint(denver_keys)
# Out:
# {'lower': 83849, 'lower_colon': 46752, 'other': 1930, 'problemchars': 0}

# %%
#people invovlved in the map editing.
def process_map(filename):
    users = set()
    for __, element in ET.iterparse(filename):
        for e in element:
            if 'uid' in e.attrib:
                users.add(e.attrib['uid'])
                
    return users

users = process_map(SAMPLE_FILE)
len(users)
# Out:
# 768

# %% [markdown]
# # 2. Problems Encountered

# %% [markdown]
#    # 2.1. Street Abbreviations

# %%
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Avenue", "Boulevard", "Commons", "Court", "Circle", "Drive", "Lane", "Parkway", 
                         "Place", "Road", "Square", "Street", "Trail", "Way"]

mapping = {'Ave'  : 'Avenue',
           'Ave.' : 'Avenue',
           'Blvd' : 'Boulevard',
           'Cir'   : 'Circle',
           'Dr'   : 'Drive',
           'Ln'   : 'Lane',
           'Pkwy' : 'Parkway',
           'Pl'   : 'Place',
           'Rd'   : 'Road',
           'Rd.'   : 'Road',
           'St'   : 'Street',
           'St.'  : 'Street',
           'street' : 'Street',
           'Ct'   : 'Court',
           'Cir'  : 'Circle',
           'Cr'   : 'Court',
           'ave'  : 'Avenue',
           'Hwg'  : 'Highway',
           'Hwy'  : 'Highway',
           'Wy'   : 'Way',
           'Sq'   : "Square"}

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for elem in get_element(osm_file, tags=('node','way')):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

# %%
denver_street_types = audit(SAMPLE_FILE)

# %%
pprint.pprint(dict(denver_street_types))
# Out:
# {'100': set(['Sheridan Boulevard #100']),
#  '2': set(['Colorado SH 2', 'Colorado SR 2']),
#  '287': set(['US Highway 287']),
#  'Ave': set(['E 6th Ave',
#              'E 72nd Ave',
#              'E Caley Ave',
#              'E Fair Ave',
#              'E Maplewood Ave',
#              'W 84th Ave']),
#  'Ave.': set(['W. Alameda Ave.']),
#  'Blvd': set(['745 Colorado Blvd',
#               'East Academy Blvd',
#               'Federal Blvd',
#               'Green Valley Ranch Blvd',
#               'S University Blvd',
#               'South Colorado Blvd',
#               'Wadsworth Blvd',
#               'Wadworth Blvd']),
#  'Broadway': set(['Broadway', 'South Broadway']),
#  'Center': set(['Garden Center']),
#  'Cir': set(['E Flatiron Cir', 'S Lake Cir']),
#  'Colfax': set(['East Colfax']),
#  'Crescent': set(['Interlocken Crescent']),
#  'Ct': set(['S Niagra Ct']),
#  'Dr': set(['Community Circle Dr']),
#  'Highway': set(['North Valley Highway']),
#  'Lincoln': set(['Lincoln']),
#  'Pl': set(['E Maplewood Pl', 'E Orchard Pl']),
#  'Rd': set(['Coalton Rd', 'E Arapahoe Rd', 'S Parker Rd']),
#  'Row': set(['Colony Row']),
#  'St': set(['Dayton St',
#             'S Broadway St',
#             'S Clayton St',
#             'S Columbine St',
#             'S Elizabeth St',
#             'S Josephine St',
#             'S Newport St',
#             'S Peoria St',
#             'S Poplar St',
#             'S Sherman St',
#             'South Grant St',
#             'Wewatta St',
#             'Wright St']),
#  'St.': set(['Pearl St.']),
#  'Tennyson': set(['Tennyson']),
#  'Varra': set(['Via Varra']),
#  'West': set(['Park Avenue West'])}

# %%
def update_name(name, mapping, regex):
    m = regex.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = re.sub(regex, mapping[street_type], name)

    return name

for street_type, ways in denver_street_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping, street_type_re)
        print name, "=>", better_name
# Out:
# East Colfax => East Colfax
# Park Avenue West => Park Avenue West
# Pearl St. => Pearl Street
# Via Varra => Via Varra
# E Arapahoe Rd => E Arapahoe Road
# Coalton Rd => Coalton Road
# S Parker Rd => S Parker Road
# North Valley Highway => North Valley Highway
# Colorado SH 2 => Colorado SH 2
# Colorado SR 2 => Colorado SR 2
# E Orchard Pl => E Orchard Place
# E Maplewood Pl => E Maplewood Place
# Community Circle Dr => Community Circle Drive
# US Highway 287 => US Highway 287
# Lincoln => Lincoln
# W. Alameda Ave. => W. Alameda Avenue
# Garden Center => Garden Center
# Tennyson => Tennyson
# S Sherman St => S Sherman Street
# S Clayton St => S Clayton Street
# Wright St => Wright Street
# S Poplar St => S Poplar Street
# South Grant St => South Grant Street
# Dayton St => Dayton Street
# Wewatta St => Wewatta Street
# S Newport St => S Newport Street
# S Elizabeth St => S Elizabeth Street
# S Peoria St => S Peoria Street
# S Broadway St => S Broadway Street
# S Josephine St => S Josephine Street
# S Columbine St => S Columbine Street
# E Flatiron Cir => E Flatiron Circle
# S Lake Cir => S Lake Circle
# W 84th Ave => W 84th Avenue
# E 6th Ave => E 6th Avenue
# E Caley Ave => E Caley Avenue
# E Maplewood Ave => E Maplewood Avenue
# E 72nd Ave => E 72nd Avenue
# E Fair Ave => E Fair Avenue
# Sheridan Boulevard #100 => Sheridan Boulevard #100
# Interlocken Crescent => Interlocken Crescent
# Wadworth Blvd => Wadworth Boulevard
# S University Blvd => S University Boulevard
# Green Valley Ranch Blvd => Green Valley Ranch Boulevard
# South Colorado Blvd => South Colorado Boulevard
# Wadsworth Blvd => Wadsworth Boulevard
# 745 Colorado Blvd => 745 Colorado Boulevard
# Federal Blvd => Federal Boulevard
# East Academy Blvd => East Academy Boulevard
# Broadway => Broadway
# South Broadway => South Broadway
# Colony Row => Colony Row
# S Niagra Ct => S Niagra Court

# %% [markdown]
#    # 2.2. Zip Code

# %%
from collections import defaultdict

def audit_zipcode(invalid_zipcodes, zipcode):
    twoDigits = zipcode[0:2]
    
    if not twoDigits.isdigit():
        invalid_zipcodes[twoDigits].add(zipcode)
    
    elif twoDigits != 80:
        invalid_zipcodes[twoDigits].add(zipcode)
        
def is_zipcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_zip(osmfile):
    osm_file = open(osmfile, "r")
    invalid_zipcodes = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_zipcode(invalid_zipcodes,tag.attrib['v'])

    return invalid_zipcodes

denver_zipcode = audit_zip(SAMPLE_FILE)

# %%
pprint.pprint(dict(denver_zipcode))
# Out:
# {'80': set(['80002',
#             '80003',
#             '80004',
#             '80010',
#             '80011',
#             '80012',
#             '80013',
#             '80014',
#             '80015',
#             '80016',
#             '80017',
#             '80018',
#             '80020',
#             '80021',
#             '80022',
#             '80023',
#             '80027',
#             '80030',
#             '80031',
#             '80033',
#             '80045',
#             '80110',
#             '80111',
#             '801111',
#             '80112',
#             '80113',
#             '80120',
#             '80121',
#             '80122',
#             '80123',
#             '80127',
#             '80202',
#             '80203',
#             '80204',
#             '80205',
#             '80206',
#             '80207',
#             '80209',
#             '80210',
#             '80211',
#             '80212',
#             '80214',
#             '80214-1801',
#             '80214-1833',
#             '80215',
#             '80216',
#             '80218',
#             '80219',
#             '80220',
#             '80221',
#             '80222',
#             '80223',
#             '80224',
#             '80226',
#             '80229',
#             '80230',
#             '80231',
#             '80232',
#             '80233',
#             '80234',
#             '80235',
#             '80237',
#             '80238',
#             '80239',
#             '80241',
#             '80246',
#             '80247',
#             '80249',
#             '80260',
#             '80601',
#             '80602',
#             '80640'])}

# %%
def update_name(zipcode):
    testNum = re.findall('[a-zA-Z]*', zipcode)
    if testNum:
        testNum = testNum[0]
    testNum.strip()
    if testNum == "CO":
        convertedZipcode = (re.findall(r'\d+', zipcode))
        if convertedZipcode:
            if convertedZipcode.__len__() == 2:
                return (re.findall(r'\d+', zipcode))[0] + "-" +(re.findall(r'\d+', zipcode))[1]
            else:
                return (re.findall(r'\d+', zipcode))[0]

for street_type, ways in denver_zipcode.iteritems():
    for name in ways:
        better_name = update_name(name)
        print name, "=>", better_name
# Out:
# 80214-1801 => None
# 80122 => None
# 801111 => None
# 80241 => None
# 80238 => None
# 80640 => None
# 80002 => None
# 80601 => None
# 80221 => None
# 80220 => None
# 80223 => None
# 80222 => None
# 80045 => None
# 80224 => None
# 80209 => None
# 80226 => None
# 80207 => None
# 80206 => None
# 80205 => None
# 80204 => None
# 80203 => None
# 80202 => None
# 80015 => None
# 80249 => None
# 80127 => None
# 80023 => None
# 80022 => None
# 80021 => None
# 80020 => None
# 80004 => None
# 80260 => None
# 80003 => None
# 80121 => None
# 80232 => None
# 80123 => None
# 80031 => None
# 80214-1833 => None
# 80247 => None
# 80113 => None
# 80219 => None
# 80017 => None
# 80111 => None
# 80027 => None
# 80218 => None
# 80233 => None
# 80230 => None
# 80231 => None
# 80030 => None
# 80237 => None
# 80234 => None
# 80235 => None
# 80210 => None
# 80211 => None
# 80212 => None
# 80239 => None
# 80214 => None
# 80215 => None
# 80216 => None
# 80246 => None
# 80229 => None
# 80033 => None
# 80120 => None
# 80018 => None
# 80602 => None
# 80016 => None
# 80112 => None
# 80014 => None
# 80110 => None
# 80012 => None
# 80013 => None
# 80010 => None
# 80011 => None

# %% [markdown]
# # 3. Convert from XML to JSON

# %%
import re
import codecs
import json

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
address_regex = re.compile(r'^addr\:')
street_regex = re.compile(r'^street')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        # YOUR CODE HERE
        node['type'] = element.tag
        # initialize empty address
        address = {}
        # parsing through attributes
        for a in element.attrib:
            if a in CREATED:
                if 'created' not in node:
                    node['created'] = {}
                node['created'][a] = element.get(a)
            elif a in ['lat', 'lon']:
                continue
            else:
                node[a] = element.get(a)
        # populate position
        if 'lat' in element.attrib and 'lon' in element.attrib:
            node['pos'] = [float(element.get('lat')), float(element.get('lon'))]

        # parse second-level tags for nodes
        for e in element:
            # parse second-level tags for ways and populate `node_refs`
            if e.tag == 'nd':
                if 'node_refs' not in node:
                    node['node_refs'] = []
                if 'ref' in e.attrib:
                    node['node_refs'].append(e.get('ref'))

            # throw out not-tag elements and elements without `k` or `v`
            if e.tag != 'tag' or 'k' not in e.attrib or 'v' not in e.attrib:
                continue
            key = e.get('k')
            val = e.get('v')

            # skip problematic characters
            if problemchars.search(key):
                continue

            # parse address k-v pairs
            elif address_regex.search(key):
                key = key.replace('addr:', '')
                address[key] = val

            # catch-all
            else:
                node[key] = val
        # compile address
        if len(address) > 0:
            node['address'] = {}
            street_full = None
            street_dict = {}
            street_format = ['prefix', 'name', 'type']
            # parse through address objects
            for key in address:
                val = address[key]
                if street_regex.search(key):
                    if key == 'street':
                        street_full = val
                    elif 'street:' in key:
                        street_dict[key.replace('street:', '')] = val
                else:
                    node['address'][key] = val
            # assign street_full or fallback to compile street dict
            if street_full:
                node['address']['street'] = street_full
            elif len(street_dict) > 0:
                node['address']['street'] = ' '.join([street_dict[key] for key in street_format])
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data
process_map(SAMPLE_FILE)
# Out:
# [{'created': {'changeset': '28505098',
#    'timestamp': '2015-01-30T13:47:30Z',
#    'uid': '2237750',
#    'user': 'chachafish',
#    'version': '4'},
#   'id': '26251251',
#   'pos': [39.9001128, -105.0807594],
#   'type': 'node'},
#  {'created': {'changeset': '28505237',
#    'timestamp': '2015-01-30T13:50:58Z',
#    'uid': '2237750',
#    'user': 'chachafish',
#    'version': '2'},
#   'id': '26251287',
#   'pos': [39.8794519, -105.0663903],
#   'type': 'node'},
#  {'created': {'changeset': '4641999',
#    'timestamp': '2010-05-08T19:17:37Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '4'},
#   'id': '26280490',
#   'pos': [39.8235601, -104.7459713],
#   'type': 'node'},
#  {'created': {'changeset': '29868003',
#    'timestamp': '2015-03-31T06:07:07Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '6'},
#   'id': '27512380',
#   'pos': [39.72954, -105.0151797],
#   'type': 'node'},
#  {'created': {'changeset': '30177046',
#    'timestamp': '2015-04-13T02:39:30Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '7'},
#   'id': '27512403',
#   'pos': [39.7182627, -105.0054139],
#   'type': 'node'},
#  {'created': {'changeset': '21967995',
#    'timestamp': '2014-04-27T04:01:19Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '6'},
#   'id': '27512443',
#   'pos': [39.7008452, -104.9870627],
#   'type': 'node'},
#  {'created': {'changeset': '1900747',
#    'timestamp': '2009-07-22T04:35:32Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '27'},
#   'id': '27548634',
#   'pos': [39.6901239, -104.9740759],
#   'type': 'node'},
#  {'created': {'changeset': '17435670',
#    'timestamp': '2013-08-21T08:43:32Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '11'},
#   'id': '27548656',
#   'pos': [39.6846857, -104.9509897],
#   'type': 'node'},
#  {'created': {'changeset': '16301873',
#    'timestamp': '2013-05-26T21:53:22Z',
#    'uid': '994480',
#    'user': 'Mark Newnham',
#    'version': '11'},
#   'id': '27548786',
#   'pos': [39.5947274, -104.8846253],
#   'type': 'node'},
#  {'created': {'changeset': '29437413',
#    'timestamp': '2015-03-12T22:09:40Z',
#    'uid': '571489',
#    'user': 'Stevestr',
#    'version': '4'},
#   'id': '32324826',
#   'pos': [39.9306773, -105.1046342],
#   'type': 'node'},
#  {'created': {'changeset': '153888',
#    'timestamp': '2007-07-19T18:45:44Z',
#    'uid': '4727',
#    'user': 'WolfMan',
#    'version': '1'},
#   'id': '32325791',
#   'pos': [39.9293728, -105.1032006],
#   'type': 'node'},
#  {'created': {'changeset': '3338276',
#    'timestamp': '2009-12-09T23:35:38Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '32329303',
#   'pos': [39.933447, -105.0957234],
#   'type': 'node'},
#  {'created': {'changeset': '3338276',
#    'timestamp': '2009-12-09T23:35:39Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '32329336',
#   'pos': [39.9298477, -105.0984646],
#   'type': 'node'},
#  {'created': {'changeset': '3338276',
#    'timestamp': '2009-12-09T23:35:40Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '32329347',
#   'pos': [39.9290353, -105.1003073],
#   'type': 'node'},
#  {'created': {'changeset': '3337144',
#    'timestamp': '2009-12-09T21:20:11Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '2'},
#   'id': '32331031',
#   'pos': [39.9299893, -105.09396],
#   'type': 'node'},
#  {'created': {'changeset': '4094804',
#    'timestamp': '2010-03-11T01:36:28Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '3'},
#   'id': '32333781',
#   'pos': [39.9322261, -105.119237],
#   'type': 'node'},
#  {'address': {'city': 'Broomfield'},
#   'amenity': 'post_box',
#   'created': {'changeset': '24681760',
#    'timestamp': '2014-08-11T15:57:30Z',
#    'uid': '2181182',
#    'user': 'WmofColo',
#    'version': '6'},
#   'id': '75693054',
#   'pos': [39.9158661, -105.0679814],
#   'type': 'node'},
#  {'created': {'changeset': '238411',
#    'timestamp': '2009-04-05T20:25:57Z',
#    'uid': '93334',
#    'user': 'Joan McEwen',
#    'version': '3'},
#   'id': '88363581',
#   'pos': [39.583265, -104.81405],
#   'type': 'node'},
#  {'created': {'changeset': '21995044',
#    'timestamp': '2014-04-28T08:48:07Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '7'},
#   'id': '89675928',
#   'pos': [39.7537699, -104.9405976],
#   'type': 'node'},
#  {'created': {'changeset': '6556642',
#    'timestamp': '2010-12-05T20:55:31Z',
#    'uid': '262151',
#    'user': 'ToeBee',
#    'version': '5'},
#   'id': '90850752',
#   'pos': [39.7801418, -104.9594928],
#   'type': 'node'},
#  {'created': {'changeset': '6582075',
#    'timestamp': '2010-12-08T05:17:25Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '6'},
#   'id': '90850765',
#   'pos': [39.7800645, -104.9884182],
#   'type': 'node'},
#  {'created': {'changeset': '9407178',
#    'timestamp': '2011-09-27T02:22:09Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '3'},
#   'id': '90850782',
#   'pos': [39.7833771, -105.0081508],
#   'type': 'node'},
#  {'created': {'changeset': '8959018',
#    'timestamp': '2011-08-08T16:33:08Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '5'},
#   'highway': 'motorway_junction',
#   'id': '106727869',
#   'pos': [39.7840126, -105.1046442],
#   'ref': '267',
#   'type': 'node'},
#  {'created': {'changeset': '6419283',
#    'timestamp': '2010-11-21T00:38:54Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '4'},
#   'id': '106727883',
#   'pos': [39.7779068, -105.1420234],
#   'type': 'node'},
#  {'created': {'changeset': '6436626',
#    'timestamp': '2010-11-23T03:11:23Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '5'},
#   'id': '106727896',
#   'pos': [39.7446939, -105.1535065],
#   'type': 'node'},
#  {'created': {'changeset': '15648558',
#    'timestamp': '2013-04-08T00:30:31Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '4'},
#   'id': '106730240',
#   'pos': [39.7851299, -105.0487197],
#   'type': 'node'},
#  {'created': {'changeset': '16558',
#    'timestamp': '2008-06-02T01:45:31Z',
#    'uid': '28887',
#    'user': 'John Martin',
#    'version': '3'},
#   'id': '106730254',
#   'pos': [39.7859479, -105.072244],
#   'type': 'node'},
#  {'created': {'changeset': '559316',
#    'timestamp': '2008-05-31T15:27:51Z',
#    'uid': '28887',
#    'user': 'John Martin',
#    'version': '2'},
#   'id': '106732068',
#   'pos': [39.7837483, -105.0304755],
#   'type': 'node'},
#  {'created': {'changeset': '145015',
#    'timestamp': '2008-12-06T13:43:35Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '1682',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Arapahoe',
#   'gnis:County_num': '005',
#   'gnis:ST_alpha': 'CO',
#   'gnis:ST_num': '08',
#   'gnis:id': '202874',
#   'id': '151363138',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Arapahoe,Colorado,Colo.,CO,USA',
#   'name': 'Bow Mar',
#   'place': 'hamlet',
#   'pos': [39.628321, -105.0499841],
#   'type': 'node'},
#  {'census:population': '909;2006',
#   'created': {'changeset': '43671726',
#    'timestamp': '2016-11-15T14:13:34Z',
#    'uid': '1943392',
#    'user': 'LogicalViolinist',
#    'version': '3'},
#   'ele': '1754',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Arapahoe',
#   'gnis:County_num': '005',
#   'gnis:ST_alpha': 'CO',
#   'gnis:ST_num': '08',
#   'gnis:id': '1669465',
#   'id': '151475086',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Arapahoe,Colorado,Colo.,CO,USA',
#   'name': 'Foxfield',
#   'place': 'village',
#   'population': '909',
#   'pos': [39.591932, -104.793091],
#   'type': 'node',
#   'wikidata': 'Q2196136'},
#  {'created': {'changeset': '145015',
#    'timestamp': '2008-12-06T13:44:38Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '1730',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Jefferson',
#   'gnis:County_num': '059',
#   'gnis:ST_alpha': 'CO',
#   'gnis:ST_num': '08',
#   'gnis:id': '181656',
#   'id': '151563585',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Jefferson,Colorado,Colo.,CO,USA',
#   'name': 'Leyden Junction',
#   'place': 'hamlet',
#   'pos': [39.8460975, -105.1483194],
#   'type': 'node'},
#  {'created': {'changeset': '43671726',
#    'timestamp': '2016-11-15T14:13:38Z',
#    'uid': '1943392',
#    'user': 'LogicalViolinist',
#    'version': '9'},
#   'ele': '1631',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Arapahoe',
#   'gnis:County_num': '005',
#   'gnis:ST_alpha': 'CO',
#   'gnis:ST_num': '08',
#   'gnis:id': '169446',
#   'id': '151635070',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'name': 'Littleton',
#   'place': 'town',
#   'population': '41737',
#   'pos': [39.613623, -105.016937],
#   'type': 'node',
#   'wikidata': 'Q953583'},
#  {'created': {'changeset': '145015',
#    'timestamp': '2008-12-06T13:45:17Z',
#    'uid': '3582',
#    'user': 'davidearl',
#    'version': '2'},
#   'ele': '1599',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Adams',
#   'gnis:County_num': '001',
#   'gnis:ST_alpha': 'CO',
#   'gnis:ST_num': '08',
#   'gnis:id': '1852852',
#   'id': '151729239',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Adams,Colorado,Colo.,CO,USA',
#   'name': 'Twin Lakes',
#   'place': 'hamlet',
#   'pos': [39.8249861, -105.0047036],
#   'type': 'node'},
#  {'census:population': '13440;2006',
#   'created': {'changeset': '43671726',
#    'timestamp': '2016-11-15T14:13:42Z',
#    'uid': '1943392',
#    'user': 'LogicalViolinist',
#    'version': '3'},
#   'ele': '1666',
#   'gnis:Class': 'Populated Place',
#   'gnis:County': 'Arapahoe',
#   'gnis:County_num': '005',
#   'gnis:ST_alpha': 'CO',
#   'gnis:ST_num': '08',
#   'gnis:id': '185037',
#   'id': '151857981',
#   'import_uuid': 'bb7269ee-502a-5391-8056-e3ce0e66489c',
#   'is_in': 'Arapahoe,Colorado,Colo.,CO,USA',
#   'name': 'Greenwood Village',
#   'place': 'town',
#   'population': '13440',
#   'pos': [39.617326, -104.951019],
#   'type': 'node',
#   'wikidata': 'Q1003256'},
#  {'created': {'changeset': '32097544',
#    'timestamp': '2015-06-20T14:07:13Z',
#    'uid': '994480',
#    'user': 'Mark Newnham',
#    'version': '4'},
#   'id': '175844200',
#   'pos': [39.7432987, -104.7138105],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:43Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844220',
#   'pos': [39.74621, -104.811293],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844261',
#   'pos': [39.869468, -104.971955],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844276',
#   'pos': [39.924881, -104.998724],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844292',
#   'pos': [39.924044, -104.997386],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844320',
#   'pos': [39.926025, -105.000215],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844518',
#   'pos': [39.74432, -104.798937],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:52Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844547',
#   'pos': [39.77145, -104.799202],
#   'type': 'node'},
#  {'created': {'changeset': '16088869',
#    'timestamp': '2013-05-12T03:20:24Z',
#    'uid': '571489',
#    'user': 'Stevestr',
#    'version': '3'},
#   'id': '175844573',
#   'pos': [39.9096422, -104.7985225],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844596',
#   'pos': [39.903679, -104.796462],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844614',
#   'pos': [39.90527, -104.794941],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:55Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844627',
#   'pos': [39.906381, -104.792205],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844689',
#   'pos': [39.894968, -104.976567],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:30:58Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844704',
#   'pos': [39.895413, -104.974434],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175844730',
#   'pos': [39.8664814, -105.0188462],
#   'type': 'node'},
#  {'created': {'changeset': '24705113',
#    'timestamp': '2014-08-12T16:02:41Z',
#    'uid': '2181182',
#    'user': 'WmofColo',
#    'version': '3'},
#   'id': '175844747',
#   'pos': [39.9002689, -105.0209792],
#   'type': 'node'},
#  {'created': {'changeset': '6800629',
#    'timestamp': '2010-12-29T17:49:07Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'highway': 'turning_circle',
#   'id': '175844766',
#   'pos': [39.8774647, -105.0197716],
#   'type': 'node'},
#  {'created': {'changeset': '32096372',
#    'timestamp': '2015-06-20T13:01:33Z',
#    'uid': '994480',
#    'user': 'Mark Newnham',
#    'version': '3'},
#   'id': '175844799',
#   'pos': [39.7469561, -104.6080248],
#   'type': 'node'},
#  {'created': {'changeset': '16023750',
#    'timestamp': '2013-05-08T06:17:30Z',
#    'uid': '571489',
#    'user': 'Stevestr',
#    'version': '3'},
#   'id': '175844843',
#   'pos': [39.8911583, -104.7910578],
#   'type': 'node'},
#  {'created': {'changeset': '20687369',
#    'timestamp': '2014-02-21T05:45:13Z',
#    'uid': '571489',
#    'user': 'Stevestr',
#    'version': '4'},
#   'id': '175844868',
#   'pos': [39.8899611, -104.8033874],
#   'type': 'node'},
#  {'created': {'changeset': '18509708',
#    'timestamp': '2013-10-23T20:19:17Z',
#    'uid': '1494110',
#    'user': 'KristenK',
#    'version': '3'},
#   'id': '175844888',
#   'pos': [39.8899916, -104.7896767],
#   'type': 'node'},
#  {'created': {'changeset': '6419572',
#    'timestamp': '2010-11-21T03:00:23Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'highway': 'turning_circle',
#   'id': '175844912',
#   'pos': [39.925615, -104.94669],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844926',
#   'pos': [39.926424, -104.94659],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844942',
#   'pos': [39.92675, -104.945142],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844969',
#   'pos': [39.927898, -104.93618],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175844990',
#   'pos': [39.937378, -104.953382],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845003',
#   'pos': [39.938969, -104.953277],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845033',
#   'pos': [39.847389, -104.956178],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845057',
#   'pos': [39.846126, -104.95685],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845079',
#   'pos': [39.868602, -104.955042],
#   'type': 'node'},
#  {'created': {'changeset': '6429200',
#    'timestamp': '2010-11-22T07:33:40Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'highway': 'turning_circle',
#   'id': '175845096',
#   'pos': [39.919446, -104.953045],
#   'type': 'node'},
#  {'created': {'changeset': '6429200',
#    'timestamp': '2010-11-22T07:20:45Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'highway': 'turning_circle',
#   'id': '175845118',
#   'pos': [39.921662, -104.95453],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845143',
#   'pos': [39.938359, -104.969164],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845155',
#   'pos': [39.939632, -104.967405],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845173',
#   'pos': [39.940337, -104.966306],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845228',
#   'pos': [39.885014, -104.970512],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845270',
#   'pos': [39.905053, -104.971236],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845287',
#   'pos': [39.907017, -104.971631],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845311',
#   'pos': [39.900539, -104.970889],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845334',
#   'pos': [39.902184, -104.971321],
#   'type': 'node'},
#  {'created': {'changeset': '5155898',
#    'timestamp': '2010-07-07T05:49:52Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175845431',
#   'pos': [39.8927071, -104.7923372],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:42Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845487',
#   'pos': [39.80825, -105.005046],
#   'type': 'node'},
#  {'created': {'changeset': '41381034',
#    'timestamp': '2016-08-11T07:01:29Z',
#    'uid': '227972',
#    'user': 'Your Village Maps',
#    'version': '3'},
#   'id': '175845502',
#   'pos': [39.8091487, -104.998545],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845524',
#   'pos': [39.809096, -104.98894],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845540',
#   'pos': [39.809108, -104.995964],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845561',
#   'pos': [39.811989, -104.99836],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:43Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845592',
#   'pos': [39.809223, -105.052528],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845609',
#   'pos': [39.809404, -105.051019],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845630',
#   'pos': [39.808734, -105.031839],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845646',
#   'pos': [39.808434, -105.034457],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845667',
#   'pos': [39.871305, -104.803047],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845685',
#   'pos': [39.874143, -104.80305],
#   'type': 'node'},
#  {'created': {'changeset': '5155898',
#    'timestamp': '2010-07-07T05:49:47Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175845722',
#   'pos': [39.8916823, -104.803404],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845756',
#   'pos': [39.890544, -104.941898],
#   'type': 'node'},
#  {'created': {'changeset': '12530170',
#    'timestamp': '2012-07-29T03:01:13Z',
#    'uid': '262151',
#    'user': 'ToeBee',
#    'version': '3'},
#   'id': '175845811',
#   'pos': [39.7537615, -104.8657816],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845829',
#   'pos': [39.830654, -104.939736],
#   'type': 'node'},
#  {'created': {'changeset': '18752118',
#    'timestamp': '2013-11-06T20:45:17Z',
#    'uid': '392708',
#    'user': 'killian',
#    'version': '3'},
#   'id': '175845890',
#   'pos': [39.8139911, -104.8226204],
#   'type': 'node'},
#  {'created': {'changeset': '18755498',
#    'timestamp': '2013-11-06T21:56:18Z',
#    'uid': '392708',
#    'user': 'killian',
#    'version': '4'},
#   'id': '175845909',
#   'pos': [39.8315348, -104.8152714],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:29Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175845940',
#   'pos': [39.907977, -104.826315],
#   'type': 'node'},
#  {'created': {'changeset': '28642373',
#    'timestamp': '2015-02-06T00:18:35Z',
#    'uid': '994480',
#    'user': 'Mark Newnham',
#    'version': '3'},
#   'id': '175845958',
#   'pos': [39.9074131, -104.8264846],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:30Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175845989',
#   'pos': [39.766534, -104.752272],
#   'type': 'node'},
#  {'created': {'changeset': '28219105',
#    'timestamp': '2015-01-17T21:37:36Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846028',
#   'pos': [39.7519646, -104.7471956],
#   'type': 'node'},
#  {'created': {'changeset': '28219105',
#    'timestamp': '2015-01-17T21:37:36Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846045',
#   'pos': [39.7521612, -104.7455103],
#   'type': 'node'},
#  {'created': {'changeset': '28219105',
#    'timestamp': '2015-01-17T21:37:36Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846077',
#   'pos': [39.7518132, -104.7413954],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:34Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175846110',
#   'pos': [39.854767, -104.952854],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:34Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175846127',
#   'pos': [39.855595, -104.950075],
#   'type': 'node'},
#  {'created': {'changeset': '17043495',
#    'timestamp': '2013-07-22T05:38:20Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175846200',
#   'pos': [39.9140264, -105.0253097],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:46Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175846215',
#   'pos': [39.865844, -105.047616],
#   'type': 'node'},
#  {'created': {'changeset': '18752118',
#    'timestamp': '2013-11-06T20:45:18Z',
#    'uid': '392708',
#    'user': 'killian',
#    'version': '3'},
#   'id': '175846238',
#   'pos': [39.8380641, -104.8343696],
#   'type': 'node'},
#  {'created': {'changeset': '18752118',
#    'timestamp': '2013-11-06T20:45:18Z',
#    'uid': '392708',
#    'user': 'killian',
#    'version': '3'},
#   'id': '175846255',
#   'pos': [39.8319948, -104.8327447],
#   'type': 'node'},
#  {'created': {'changeset': '28103465',
#    'timestamp': '2015-01-13T05:31:46Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846279',
#   'pos': [39.8125305, -104.9354303],
#   'type': 'node'},
#  {'created': {'changeset': '28103465',
#    'timestamp': '2015-01-13T05:31:46Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846364',
#   'pos': [39.8126899, -104.9352593],
#   'type': 'node'},
#  {'created': {'changeset': '28103465',
#    'timestamp': '2015-01-13T05:31:44Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846540',
#   'pos': [39.8084, -104.938743],
#   'type': 'node'},
#  {'created': {'changeset': '28103465',
#    'timestamp': '2015-01-13T05:31:45Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846556',
#   'pos': [39.8122171, -104.9356875],
#   'type': 'node'},
#  {'created': {'changeset': '28103465',
#    'timestamp': '2015-01-13T05:31:44Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846664',
#   'pos': [39.8095499, -104.9383107],
#   'type': 'node'},
#  {'created': {'changeset': '20994746',
#    'timestamp': '2014-03-08T20:59:13Z',
#    'uid': '571489',
#    'user': 'Stevestr',
#    'version': '3'},
#   'id': '175846698',
#   'pos': [39.9073447, -104.8243032],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:53Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175846717',
#   'pos': [39.910187, -104.821933],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:31:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175846741',
#   'pos': [39.809032, -104.937213],
#   'type': 'node'},
#  {'created': {'changeset': '28103639',
#    'timestamp': '2015-01-13T05:55:18Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846762',
#   'pos': [39.8110395, -104.9332342],
#   'type': 'node'},
#  {'created': {'changeset': '28103639',
#    'timestamp': '2015-01-13T05:55:18Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846788',
#   'pos': [39.8123571, -104.933073],
#   'type': 'node'},
#  {'created': {'changeset': '28125775',
#    'timestamp': '2015-01-14T01:06:45Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846811',
#   'pos': [39.8108784, -104.9384063],
#   'type': 'node'},
#  {'created': {'changeset': '28220878',
#    'timestamp': '2015-01-17T23:23:02Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175846962',
#   'pos': [39.7458107, -104.6033452],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847084',
#   'pos': [39.856095, -104.914119],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847102',
#   'pos': [39.85744, -104.912016],
#   'type': 'node'},
#  {'created': {'changeset': '13781887',
#    'timestamp': '2012-11-07T07:20:29Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '4'},
#   'id': '175847119',
#   'pos': [39.9004985, -104.9222819],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847243',
#   'pos': [39.79912, -104.985669],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847257',
#   'pos': [39.801872, -104.983787],
#   'type': 'node'},
#  {'created': {'changeset': '4975268',
#    'timestamp': '2010-06-13T04:09:47Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '4'},
#   'id': '175847281',
#   'pos': [39.7409586, -104.6614286],
#   'type': 'node'},
#  {'created': {'changeset': '4975268',
#    'timestamp': '2010-06-13T04:09:48Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '4'},
#   'id': '175847306',
#   'pos': [39.7405915, -104.6570324],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:47Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847336',
#   'pos': [39.858357, -105.00171],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847361',
#   'pos': [39.765851, -104.792728],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847380',
#   'pos': [39.764391, -104.791472],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847446',
#   'pos': [39.749107, -104.786531],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847498',
#   'pos': [39.867935, -104.903779],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175847521',
#   'pos': [39.87398, -104.898381],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847549',
#   'pos': [39.872834, -104.90024],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175847720',
#   'pos': [39.9111834, -104.9396129],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175847742',
#   'pos': [39.9106435, -104.9374843],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847771',
#   'pos': [39.828756, -104.999767],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175847788',
#   'pos': [39.830961, -105.007997],
#   'type': 'node'},
#  {'created': {'changeset': '9416004',
#    'timestamp': '2011-09-28T03:40:24Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '3'},
#   'id': '175847921',
#   'pos': [39.7911537, -104.9988101],
#   'type': 'node'},
#  {'created': {'changeset': '28010698',
#    'timestamp': '2015-01-09T02:22:41Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175847939',
#   'pos': [39.7965186, -104.9986906],
#   'type': 'node'},
#  {'created': {'changeset': '28101654',
#    'timestamp': '2015-01-13T01:37:03Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175847968',
#   'pos': [39.7959742, -104.9993496],
#   'type': 'node'},
#  {'created': {'changeset': '28010698',
#    'timestamp': '2015-01-09T02:22:42Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175848017',
#   'pos': [39.7976251, -104.9978207],
#   'type': 'node'},
#  {'created': {'changeset': '28010698',
#    'timestamp': '2015-01-09T02:22:41Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175848040',
#   'pos': [39.7966926, -104.9987271],
#   'type': 'node'},
#  {'created': {'changeset': '28010636',
#    'timestamp': '2015-01-09T02:07:29Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175848059',
#   'pos': [39.7987379, -104.9986362],
#   'type': 'node'},
#  {'created': {'changeset': '5152355',
#    'timestamp': '2010-07-06T18:56:16Z',
#    'uid': '123364',
#    'user': 'Tronikon',
#    'version': '3'},
#   'id': '175848077',
#   'pos': [39.8012151, -104.9997591],
#   'type': 'node'},
#  {'created': {'changeset': '5152355',
#    'timestamp': '2010-07-06T18:56:17Z',
#    'uid': '123364',
#    'user': 'Tronikon',
#    'version': '3'},
#   'id': '175848095',
#   'pos': [39.802978, -105.0022267],
#   'type': 'node'},
#  {'created': {'changeset': '5152355',
#    'timestamp': '2010-07-06T18:56:58Z',
#    'uid': '123364',
#    'user': 'Tronikon',
#    'version': '3'},
#   'id': '175848114',
#   'pos': [39.8031913, -105.0057752],
#   'type': 'node'},
#  {'created': {'changeset': '28010698',
#    'timestamp': '2015-01-09T02:22:40Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175848149',
#   'pos': [39.7970608, -104.998826],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848178',
#   'pos': [39.883196, -104.762356],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848199',
#   'pos': [39.886051, -104.762966],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:32:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848218',
#   'pos': [39.890718, -104.762141],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848296',
#   'pos': [39.834364, -105.018018],
#   'type': 'node'},
#  {'created': {'changeset': '3505120',
#    'timestamp': '2010-01-01T02:49:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848313',
#   'pos': [39.836213, -105.023442],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:01:53Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848332',
#   'pos': [39.837536, -105.024641],
#   'type': 'node'},
#  {'created': {'changeset': '4230625',
#    'timestamp': '2010-03-25T17:06:27Z',
#    'uid': '155796',
#    'user': 'PipeManMusic',
#    'version': '3'},
#   'id': '175848358',
#   'pos': [39.9048017, -104.983283],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:01:54Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848374',
#   'pos': [39.799718, -105.025014],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:01:55Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175848393',
#   'pos': [39.802272, -105.020336],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:01:56Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848447',
#   'pos': [39.804297, -104.968666],
#   'type': 'node'},
#  {'created': {'changeset': '28219105',
#    'timestamp': '2015-01-17T21:37:37Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175848489',
#   'pos': [39.7515003, -104.7434949],
#   'type': 'node'},
#  {'created': {'changeset': '40348457',
#    'timestamp': '2016-06-28T16:59:33Z',
#    'uid': '2508151',
#    'user': 'ridixcr',
#    'version': '6'},
#   'id': '175848589',
#   'pos': [39.7703406, -104.8103641],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175848611',
#   'pos': [39.7700983, -104.8065536],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:02Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848675',
#   'pos': [39.845824, -104.985129],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:03Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848692',
#   'pos': [39.848922, -104.986927],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848716',
#   'pos': [39.84825, -104.98467],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848743',
#   'pos': [39.848865, -104.984048],
#   'type': 'node'},
#  {'created': {'changeset': '28219799',
#    'timestamp': '2015-01-17T22:14:37Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175848849',
#   'pos': [39.7681862, -104.8541491],
#   'type': 'node'},
#  {'created': {'changeset': '28622088',
#    'timestamp': '2015-02-05T00:01:57Z',
#    'uid': '994480',
#    'user': 'Mark Newnham',
#    'version': '4'},
#   'highway': 'traffic_signals',
#   'id': '175848953',
#   'pos': [39.8131922, -104.9306969],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175848985',
#   'pos': [39.741662, -104.817867],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175849036',
#   'pos': [39.798816, -104.933707],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175849058',
#   'pos': [39.798617, -104.933011],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175849072',
#   'pos': [39.799019, -104.93258],
#   'type': 'node'},
#  {'created': {'changeset': '17044064',
#    'timestamp': '2013-07-22T05:53:34Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '4'},
#   'id': '175849094',
#   'pos': [39.913004, -105.0049418],
#   'type': 'node'},
#  {'created': {'changeset': '13781887',
#    'timestamp': '2012-11-07T07:58:54Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '5'},
#   'highway': 'traffic_signals',
#   'id': '175849118',
#   'pos': [39.9123971, -104.9968297],
#   'type': 'node'},
#  {'created': {'changeset': '8716046',
#    'timestamp': '2011-07-13T20:20:04Z',
#    'uid': '338293',
#    'user': 'RLugo',
#    'version': '3'},
#   'id': '175849262',
#   'pos': [39.8272263, -104.857347],
#   'type': 'node'},
#  {'created': {'changeset': '18755498',
#    'timestamp': '2013-11-06T22:38:12Z',
#    'uid': '392708',
#    'user': 'killian',
#    'version': '3'},
#   'id': '175849279',
#   'pos': [39.8299861, -104.8600101],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175849302',
#   'pos': [39.827643, -104.860192],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:18Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175849348',
#   'pos': [39.821811, -104.858884],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175849363',
#   'pos': [39.82218, -104.85794],
#   'type': 'node'},
#  {'created': {'changeset': '18752118',
#    'timestamp': '2013-11-06T20:45:19Z',
#    'uid': '392708',
#    'user': 'killian',
#    'version': '3'},
#   'id': '175849384',
#   'pos': [39.8209382, -104.855964],
#   'type': 'node'},
#  {'created': {'changeset': '18752118',
#    'timestamp': '2013-11-06T20:45:19Z',
#    'uid': '392708',
#    'user': 'killian',
#    'version': '3'},
#   'id': '175849403',
#   'pos': [39.8188853, -104.8481454],
#   'type': 'node'},
#  {'created': {'changeset': '26072046',
#    'timestamp': '2014-10-14T13:26:37Z',
#    'uid': '2237750',
#    'user': 'chachafish',
#    'version': '3'},
#   'id': '175849514',
#   'pos': [39.8071708, -105.0108793],
#   'type': 'node'},
#  {'created': {'changeset': '12993133',
#    'timestamp': '2012-09-05T09:17:56Z',
#    'uid': '207745',
#    'user': 'NE2',
#    'version': '3'},
#   'id': '175849539',
#   'pos': [39.8083049, -105.0055423],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175849560',
#   'pos': [39.809887, -105.000588],
#   'type': 'node'},
#  {'created': {'changeset': '28101956',
#    'timestamp': '2015-01-13T02:26:37Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175849578',
#   'pos': [39.801727, -105.001883],
#   'type': 'node'},
#  {'created': {'changeset': '28101956',
#    'timestamp': '2015-01-13T02:26:36Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175849596',
#   'pos': [39.7998693, -104.9995521],
#   'type': 'node'},
#  {'created': {'changeset': '28010698',
#    'timestamp': '2015-01-09T02:22:40Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175849622',
#   'pos': [39.7977988, -104.9987022],
#   'type': 'node'},
#  {'created': {'changeset': '28101453',
#    'timestamp': '2015-01-13T01:04:45Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175849658',
#   'pos': [39.7972673, -104.9992488],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:27Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175849715',
#   'pos': [39.795961, -104.998387],
#   'type': 'node'},
#  {'created': {'changeset': '4229326',
#    'timestamp': '2010-03-25T14:07:48Z',
#    'uid': '155796',
#    'user': 'PipeManMusic',
#    'version': '3'},
#   'id': '175849826',
#   'pos': [39.913804, -104.957946],
#   'type': 'node'},
#  {'created': {'changeset': '28103465',
#    'timestamp': '2015-01-13T05:31:45Z',
#    'uid': '711717',
#    'user': 'railfan-eric',
#    'version': '3'},
#   'id': '175849890',
#   'pos': [39.8114857, -104.9369374],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175849910',
#   'pos': [39.907576, -104.875643],
#   'type': 'node'},
#  {'created': {'changeset': '21599388',
#    'timestamp': '2014-04-10T03:58:44Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175849937',
#   'pos': [39.9377644, -104.8482305],
#   'type': 'node'},
#  {'created': {'changeset': '21599388',
#    'timestamp': '2014-04-10T03:58:44Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175849959',
#   'pos': [39.9401945, -104.8474997],
#   'type': 'node'},
#  {'created': {'changeset': '21599388',
#    'timestamp': '2014-04-10T03:58:44Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175849973',
#   'pos': [39.9417465, -104.8480793],
#   'type': 'node'},
#  {'created': {'changeset': '21599388',
#    'timestamp': '2014-04-10T03:58:44Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175849989',
#   'pos': [39.9418914, -104.8499537],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:34Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175850049',
#   'pos': [39.861749, -104.880257],
#   'type': 'node'},
#  {'created': {'changeset': '20744331',
#    'timestamp': '2014-02-24T04:07:54Z',
#    'uid': '571489',
#    'user': 'Stevestr',
#    'version': '3'},
#   'id': '175850069',
#   'pos': [39.8620647, -104.8760071],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:36Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175850096',
#   'pos': [39.857543, -104.881006],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:36Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175850118',
#   'pos': [39.860267, -104.879259],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:37Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175850144',
#   'pos': [39.860628, -104.877694],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:38Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175850211',
#   'pos': [39.811553, -104.931301],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:39Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175850230',
#   'pos': [39.912549, -104.779902],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:40Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175850258',
#   'pos': [39.915821, -104.782245],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:40Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175850285',
#   'pos': [39.911515, -104.780272],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:40Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175850296',
#   'pos': [39.914278, -104.7833266],
#   'type': 'node'},
#  {'created': {'changeset': '3437344',
#    'timestamp': '2009-12-23T20:05:22Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175850312',
#   'pos': [39.9178411, -104.7869949],
#   'type': 'node'},
#  {'created': {'changeset': '21599388',
#    'timestamp': '2014-04-10T03:58:45Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175850354',
#   'pos': [39.9419381, -104.8494721],
#   'type': 'node'},
#  {'created': {'changeset': '21599388',
#    'timestamp': '2014-04-10T03:58:45Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175850374',
#   'pos': [39.9417056, -104.8481691],
#   'type': 'node'},
#  {'created': {'changeset': '21599388',
#    'timestamp': '2014-04-10T03:58:45Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175850388',
#   'pos': [39.9407328, -104.8474973],
#   'type': 'node'},
#  {'created': {'changeset': '3382932',
#    'timestamp': '2009-12-15T21:02:43Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175850407',
#   'pos': [39.939706, -104.848061],
#   'type': 'node'},
# ...
#    'version': '2'},
#   'id': '175885887',
#   'pos': [39.821237, -104.973291],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175885908',
#   'pos': [39.876295, -104.972908],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:55Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175885927',
#   'pos': [39.939314, -104.971894],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:55Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175885943',
#   'pos': [39.858498, -104.97145],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175885991',
#   'pos': [39.905057, -104.972184],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886013',
#   'pos': [39.907001, -104.97263],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:18Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886038',
#   'pos': [39.843817, -104.972711],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:56Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886061',
#   'pos': [39.840319, -104.971813],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:56Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886081',
#   'pos': [39.838869, -104.972205],
#   'type': 'node'},
#  {'created': {'changeset': '2917546',
#    'timestamp': '2009-10-22T00:04:54Z',
#    'uid': '139555',
#    'user': 'DavidJDBA',
#    'version': '3'},
#   'id': '175886097',
#   'pos': [39.8842318, -104.972871],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:19Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886127',
#   'pos': [39.89087, -104.971801],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886153',
#   'pos': [39.885947, -104.972426],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:20Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886170',
#   'pos': [39.951224, -104.973535],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:57Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886210',
#   'pos': [39.860394, -104.956372],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:58Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886246',
#   'pos': [39.838446, -105.019348],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:58Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886267',
#   'pos': [39.841171, -105.020314],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886284',
#   'pos': [39.830727, -104.99709],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886298',
#   'pos': [39.830969, -104.998738],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886322',
#   'pos': [39.832814, -104.991826],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:59Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886338',
#   'pos': [39.874764, -105.010782],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:06:59Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886356',
#   'pos': [39.877536, -105.010456],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886412',
#   'pos': [39.891472, -104.868477],
#   'type': 'node'},
#  {'created': {'changeset': '40342057',
#    'timestamp': '2016-06-28T12:05:44Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '3'},
#   'id': '175886428',
#   'pos': [39.8499248, -104.9550849],
#   'type': 'node'},
#  {'created': {'changeset': '40342057',
#    'timestamp': '2016-06-28T12:05:44Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '4'},
#   'id': '175886448',
#   'pos': [39.8533373, -104.9558031],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:01Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886469',
#   'pos': [39.838144, -105.036901],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:43Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886499',
#   'pos': [39.839526, -105.037325],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886659',
#   'pos': [39.850963, -104.96469],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886679',
#   'pos': [39.839244, -104.985621],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:28Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886695',
#   'pos': [39.840073, -104.987353],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886713',
#   'pos': [39.829379, -104.99624],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886735',
#   'pos': [39.831389, -104.991357],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:04Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175886753',
#   'pos': [39.796874, -104.929837],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:30Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175886770',
#   'pos': [39.794966, -104.925585],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175886792',
#   'pos': [39.794314, -104.921055],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:31Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175886812',
#   'pos': [39.793802, -104.915457],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175886831',
#   'pos': [39.791698, -104.91131],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:05Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '175886852',
#   'pos': [39.789448, -104.907339],
#   'type': 'node'},
#  {'created': {'changeset': '12767731',
#    'timestamp': '2012-08-17T21:56:35Z',
#    'uid': '392708',
#    'user': 'killian',
#    'version': '4'},
#   'id': '175886893',
#   'pos': [39.78688, -104.9037632],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:06Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886935',
#   'pos': [39.851337, -105.041964],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886957',
#   'pos': [39.852931, -105.045855],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175886975',
#   'pos': [39.853398, -105.04761],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887007',
#   'pos': [39.872226, -105.034977],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:07Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887031',
#   'pos': [39.885737, -105.035018],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:08Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887045',
#   'pos': [39.887023, -105.034653],
#   'type': 'node'},
#  {'created': {'changeset': '41396806',
#    'timestamp': '2016-08-11T20:03:40Z',
#    'uid': '2281193',
#    'user': 'CornCO',
#    'version': '3'},
#   'id': '175887061',
#   'pos': [39.8881192, -105.0347738],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:46Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887084',
#   'pos': [39.886234, -105.035264],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:46Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887112',
#   'pos': [39.871193, -105.035041],
#   'type': 'node'},
#  {'created': {'changeset': '3959752',
#    'timestamp': '2010-02-24T02:21:33Z',
#    'uid': '1679',
#    'user': 'andrewpmk',
#    'version': '3'},
#   'highway': 'turning_circle',
#   'id': '175887135',
#   'pos': [39.920044, -104.912936],
#   'source': 'Yahoo',
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887162',
#   'pos': [39.919935, -104.913213],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:34Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887200',
#   'pos': [39.91972, -104.909327],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887230',
#   'pos': [39.896682, -105.039472],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887288',
#   'pos': [39.897022, -105.018392],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:47Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887308',
#   'pos': [39.897837, -105.019224],
#   'type': 'node'},
#  {'created': {'changeset': '21524493',
#    'timestamp': '2014-04-06T02:22:50Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175887332',
#   'pos': [39.8978263, -105.0228073],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887356',
#   'pos': [39.898347, -105.001788],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887378',
#   'pos': [39.897348, -105.005472],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887404',
#   'pos': [39.897404, -105.043664],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887425',
#   'pos': [39.897642, -105.041849],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887455',
#   'pos': [39.896972, -105.037789],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887476',
#   'pos': [39.8974, -105.03704],
#   'type': 'node'},
#  {'created': {'changeset': '3563371',
#    'timestamp': '2010-01-07T16:39:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887502',
#   'pos': [39.897138, -105.037215],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887530',
#   'pos': [39.89742, -105.035808],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887552',
#   'pos': [39.897574, -105.035897],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:34Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887582',
#   'pos': [39.932149, -104.935068],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:35Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887601',
#   'pos': [39.930873, -104.937081],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:35Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887611',
#   'pos': [39.904444, -104.932979],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887621',
#   'pos': [39.905543, -104.933471],
#   'type': 'node'},
#  {'created': {'changeset': '3144321',
#    'timestamp': '2009-11-17T19:29:05Z',
#    'uid': '117055',
#    'user': 'GPS_dr',
#    'version': '3'},
#   'id': '175887637',
#   'pos': [39.90728, -104.934114],
#   'type': 'node'},
#  {'created': {'changeset': '2478758',
#    'timestamp': '2009-09-14T09:07:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887655',
#   'pos': [39.908989, -104.934222],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:37Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887673',
#   'pos': [39.910488, -104.933599],
#   'type': 'node'},
#  {'created': {'changeset': '3505157',
#    'timestamp': '2010-01-01T03:38:37Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '175887688',
#   'pos': [39.912005, -104.93365],
#   'type': 'node'},
#  {'created': {'changeset': '43104370',
#    'timestamp': '2016-10-23T16:55:30Z',
#    'uid': '4720805',
#    'user': 'BobBelcher',
#    'version': '5'},
#   'highway': 'traffic_signals',
#   'id': '175887710',
#   'pos': [39.9139768, -104.9327723],
#   'traffic_signals': 'signal',
#   'type': 'node'},
#  ...]

# %% [markdown]
# # 4. Dataoverview with MongoDB

# %%
#!pip install pymongo
import signal
import subprocess
pro = subprocess.Popen('mongod', preexec_fn = os.setsid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e40895205bf0> in <module>()
#       2 import signal
#       3 import subprocess
# ----> 4 pro = subprocess.Popen('mongod', preexec_fn = os.setsid)
#
# NameError: name 'os' is not defined
